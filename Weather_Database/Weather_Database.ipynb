# %%
#Import the dependences
import pandas as pd
import numpy as np
from citipy import citipy

#import the requests library
import requests

#import the API Key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_description = city_weather['weather'][0]['description']
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date,
                              "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bourail
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | bafut
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | avera
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | isiro
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | caravelas
# Processing Record 16 of Set 1 | mayor pablo lagerenza
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | tolyatti
# Processing Record 20 of Set 1 | mikuni
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | kihei
# Processing Record 24 of Set 1 | havre-saint-pierre
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | westport
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | nuevo progreso
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | coahuayana
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | borovoy
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | magna
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | rogers
# Processing Record 42 of Set 1 | sulangan
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | high level
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | bairiki
# Processing Record 50 of Set 1 | porto walter
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | morganton
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | paita
# Processing Record 7 of Set 2 | rio rancho
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | patacamaya
# Processing Record 10 of Set 2 | hornepayne
# Processing Record 11 of Set 2 | moscow
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | soddy-daisy
# Processing Record 19 of Set 2 | hudiksvall
# Processing Record 20 of Set 2 | nuristan
# Processing Record 21 of Set 2 | tambopata
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | burica
# City not found. Skipping...
# Processing Record 24 of Set 2 | sur
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | brigantine
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | san policarpo
# Processing Record 31 of Set 2 | shakawe
# Processing Record 32 of Set 2 | oktyabrskiy
# Processing Record 33 of Set 2 | fare
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | lewiston
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | port augusta
# Processing Record 40 of Set 2 | hanmer springs
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | novyy urengoy
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | ocean city
# Processing Record 49 of Set 2 | buala
# Processing Record 50 of Set 2 | sosua
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | los llanos de aridane
# Processing Record 3 of Set 3 | mao
# Processing Record 4 of Set 3 | hami
# Processing Record 5 of Set 3 | la ronge
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | ruteng
# Processing Record 8 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 3 | kangaatsiaq
# Processing Record 10 of Set 3 | galbshtadt
# Processing Record 11 of Set 3 | vallenar
# Processing Record 12 of Set 3 | brae
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | nueve de julio
# Processing Record 15 of Set 3 | menongue
# Processing Record 16 of Set 3 | surt
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | baruun-urt
# Processing Record 20 of Set 3 | flin flon
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | masunga
# Processing Record 23 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | acacoyagua
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | camacupa
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | marzuq
# Processing Record 31 of Set 3 | kokopo
# Processing Record 32 of Set 3 | deder
# Processing Record 33 of Set 3 | hauterive
# Processing Record 34 of Set 3 | koidu
# Processing Record 35 of Set 3 | tooele
# Processing Record 36 of Set 3 | sarkand
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | shkotovo-26
# City not found. Skipping...
# Processing Record 39 of Set 3 | port-gentil
# Processing Record 40 of Set 3 | vysokogornyy
# Processing Record 41 of Set 3 | raga
# Processing Record 42 of Set 3 | lata
# Processing Record 43 of Set 3 | mizan teferi
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | porto novo
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | tateyama
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | volsk
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | boden
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | hay river
# Processing Record 9 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | broken hill
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | aybak
# City not found. Skipping...
# Processing Record 14 of Set 4 | tulun
# Processing Record 15 of Set 4 | itarema
# Processing Record 16 of Set 4 | orillia
# Processing Record 17 of Set 4 | taldan
# Processing Record 18 of Set 4 | soyo
# Processing Record 19 of Set 4 | mozhga
# Processing Record 20 of Set 4 | hofn
# Processing Record 21 of Set 4 | waddan
# Processing Record 22 of Set 4 | sao filipe
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | aksarka
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | kaputa
# Processing Record 27 of Set 4 | half moon bay
# Processing Record 28 of Set 4 | balkhash
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | barrow
# Processing Record 33 of Set 4 | yar-sale
# Processing Record 34 of Set 4 | zhigansk
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | aitape
# Processing Record 37 of Set 4 | kismayo
# Processing Record 38 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 39 of Set 4 | porto de moz
# Processing Record 40 of Set 4 | nizhneangarsk
# Processing Record 41 of Set 4 | fuyang
# Processing Record 42 of Set 4 | augusto correa
# Processing Record 43 of Set 4 | bandundu
# Processing Record 44 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 4 | smithers
# Processing Record 46 of Set 4 | ilula
# Processing Record 47 of Set 4 | codrington
# Processing Record 48 of Set 4 | naze
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | merauke
# Processing Record 3 of Set 5 | palana
# Processing Record 4 of Set 5 | mizdah
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | issaquah
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | tigil
# Processing Record 10 of Set 5 | vanimo
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | san jeronimo
# Processing Record 13 of Set 5 | loncoche
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | turayf
# Processing Record 16 of Set 5 | buluang
# Processing Record 17 of Set 5 | vaitape
# Processing Record 18 of Set 5 | marovoay
# Processing Record 19 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 5 | dawson creek
# Processing Record 21 of Set 5 | otjimbingwe
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | kahta
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | caohai
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | nchelenge
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | kununurra
# Processing Record 33 of Set 5 | tuy hoa
# Processing Record 34 of Set 5 | ndele
# Processing Record 35 of Set 5 | aksha
# Processing Record 36 of Set 5 | ceres
# Processing Record 37 of Set 5 | bethanien
# Processing Record 38 of Set 5 | polunochnoye
# Processing Record 39 of Set 5 | hearst
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | butembo
# Processing Record 42 of Set 5 | tiarei
# Processing Record 43 of Set 5 | maldonado
# Processing Record 44 of Set 5 | nova soure
# Processing Record 45 of Set 5 | lamu
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | el dorado
# Processing Record 48 of Set 5 | easley
# Processing Record 49 of Set 5 | yenagoa
# Processing Record 50 of Set 5 | fuzhou
# Processing Record 1 of Set 6 | fukue
# Processing Record 2 of Set 6 | cockburn town
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | shitkino
# Processing Record 5 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | algiers
# Processing Record 8 of Set 6 | srednekolymsk
# Processing Record 9 of Set 6 | beringovskiy
# Processing Record 10 of Set 6 | mawlaik
# Processing Record 11 of Set 6 | adrar
# Processing Record 12 of Set 6 | dingle
# Processing Record 13 of Set 6 | ketchikan
# Processing Record 14 of Set 6 | nuevo casas grandes
# Processing Record 15 of Set 6 | kemijarvi
# Processing Record 16 of Set 6 | abu samrah
# Processing Record 17 of Set 6 | mehamn
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | geylegphug
# City not found. Skipping...
# Processing Record 20 of Set 6 | chemal
# Processing Record 21 of Set 6 | sao bernardo
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | homa bay
# Processing Record 24 of Set 6 | mugur-aksy
# Processing Record 25 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 6 | gillette
# Processing Record 27 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 6 | dustlik
# Processing Record 29 of Set 6 | vagur
# Processing Record 30 of Set 6 | paralimni
# Processing Record 31 of Set 6 | fort frances
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 34 of Set 6 | te anau
# Processing Record 35 of Set 6 | nizhnevartovsk
# Processing Record 36 of Set 6 | meadow lake
# Processing Record 37 of Set 6 | mitsamiouli
# Processing Record 38 of Set 6 | japura
# Processing Record 39 of Set 6 | apac
# Processing Record 40 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 6 | namibe
# Processing Record 43 of Set 6 | magdagachi
# Processing Record 44 of Set 6 | kamaishi
# Processing Record 45 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 46 of Set 6 | gizo
# Processing Record 47 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 6 | bonavista
# Processing Record 49 of Set 6 | troitsko-pechorsk
# Processing Record 50 of Set 6 | khani
# Processing Record 1 of Set 7 | christchurch
# Processing Record 2 of Set 7 | wad madani
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | teknaf
# Processing Record 5 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 7 | bredy
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | port victoria
# Processing Record 9 of Set 7 | egvekinot
# Processing Record 10 of Set 7 | salalah
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | abong mbang
# Processing Record 13 of Set 7 | saint-joseph
# Processing Record 14 of Set 7 | saskylakh
# Processing Record 15 of Set 7 | nuuk
# Processing Record 16 of Set 7 | jalu
# Processing Record 17 of Set 7 | sergeyevka
# Processing Record 18 of Set 7 | bacolod
# Processing Record 19 of Set 7 | aklavik
# Processing Record 20 of Set 7 | deputatskiy
# Processing Record 21 of Set 7 | sambava
# Processing Record 22 of Set 7 | moussoro
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | pak phanang
# Processing Record 25 of Set 7 | balakhninskiy
# Processing Record 26 of Set 7 | cap malheureux
# Processing Record 27 of Set 7 | rapid city
# Processing Record 28 of Set 7 | saraza
# Processing Record 29 of Set 7 | luwuk
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | ukiah
# Processing Record 32 of Set 7 | chickasha
# Processing Record 33 of Set 7 | scarborough
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | moskovskiy
# Processing Record 36 of Set 7 | miri
# Processing Record 37 of Set 7 | nanortalik
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | galle
# Processing Record 40 of Set 7 | sao joao da barra
# Processing Record 41 of Set 7 | ca mau
# Processing Record 42 of Set 7 | yatou
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | barguzin
# Processing Record 45 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 46 of Set 7 | sept-iles
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | batticaloa
# Processing Record 49 of Set 7 | henties bay
# Processing Record 50 of Set 7 | turka
# Processing Record 1 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 8 | yerbogachen
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | aksu
# Processing Record 5 of Set 8 | fernandina beach
# Processing Record 6 of Set 8 | catemaco
# Processing Record 7 of Set 8 | khor
# Processing Record 8 of Set 8 | muros
# Processing Record 9 of Set 8 | tinqueux
# Processing Record 10 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 11 of Set 8 | batsfjord
# Processing Record 12 of Set 8 | along
# Processing Record 13 of Set 8 | tilichiki
# Processing Record 14 of Set 8 | jumla
# Processing Record 15 of Set 8 | batagay
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | kibakwe
# Processing Record 18 of Set 8 | black river
# Processing Record 19 of Set 8 | ayr
# Processing Record 20 of Set 8 | konevo
# Processing Record 21 of Set 8 | nyurba
# Processing Record 22 of Set 8 | madang
# Processing Record 23 of Set 8 | dzhebariki-khaya
# Processing Record 24 of Set 8 | ganzhou
# Processing Record 25 of Set 8 | teyateyaneng
# Processing Record 26 of Set 8 | coolum beach
# Processing Record 27 of Set 8 | tuatapere
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | palu
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | hasaki
# Processing Record 32 of Set 8 | robstown
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 8 | zyryanka
# Processing Record 36 of Set 8 | baherden
# Processing Record 37 of Set 8 | angoram
# Processing Record 38 of Set 8 | usinsk
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | siilinjarvi
# Processing Record 42 of Set 8 | shimanovsk
# Processing Record 43 of Set 8 | monywa
# Processing Record 44 of Set 8 | richards bay
# Processing Record 45 of Set 8 | kostomuksha
# Processing Record 46 of Set 8 | gat
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | omsukchan
# Processing Record 49 of Set 8 | haflong
# Processing Record 50 of Set 8 | huilong
# Processing Record 1 of Set 9 | whitehorse
# Processing Record 2 of Set 9 | presidente medici
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 9 | laguna
# Processing Record 6 of Set 9 | san jose de rio tinto
# Processing Record 7 of Set 9 | kathu
# Processing Record 8 of Set 9 | mahebourg
# Processing Record 9 of Set 9 | marsh harbour
# Processing Record 10 of Set 9 | olinda
# Processing Record 11 of Set 9 | taoudenni
# Processing Record 12 of Set 9 | batagay-alyta
# Processing Record 13 of Set 9 | tocantinopolis
# City not found. Skipping...
# Processing Record 14 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 9 | basco
# Processing Record 16 of Set 9 | bengkulu
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | novyy buh
# Processing Record 19 of Set 9 | bella union
# Processing Record 20 of Set 9 | nabire
# Processing Record 21 of Set 9 | tessalit
# Processing Record 22 of Set 9 | middle island
# Processing Record 23 of Set 9 | north bend
# Processing Record 24 of Set 9 | masallatah
# Processing Record 25 of Set 9 | ust-tsilma
# Processing Record 26 of Set 9 | moron
# Processing Record 27 of Set 9 | nesebar
# Processing Record 28 of Set 9 | yuli
# Processing Record 29 of Set 9 | najran
# Processing Record 30 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 9 | takoradi
# Processing Record 32 of Set 9 | maceio
# Processing Record 33 of Set 9 | untsukul
# Processing Record 34 of Set 9 | toora-khem
# Processing Record 35 of Set 9 | bako
# Processing Record 36 of Set 9 | norfolk
# Processing Record 37 of Set 9 | bridlington
# Processing Record 38 of Set 9 | rio gallegos
# Processing Record 39 of Set 9 | broome
# Processing Record 40 of Set 9 | wuhu
# Processing Record 41 of Set 9 | portland
# Processing Record 42 of Set 9 | great bend
# Processing Record 43 of Set 9 | goderich
# Processing Record 44 of Set 9 | sattahip
# Processing Record 45 of Set 9 | bubaque
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | peniche
# Processing Record 48 of Set 9 | umm lajj
# Processing Record 49 of Set 9 | juneau
# Processing Record 50 of Set 9 | maniwaki
# Processing Record 1 of Set 10 | dakar
# Processing Record 2 of Set 10 | baoning
# Processing Record 3 of Set 10 | moose factory
# Processing Record 4 of Set 10 | skibbereen
# Processing Record 5 of Set 10 | borborema
# Processing Record 6 of Set 10 | litovko
# Processing Record 7 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 8 of Set 10 | bowen
# Processing Record 9 of Set 10 | rio grande
# Processing Record 10 of Set 10 | baker city
# Processing Record 11 of Set 10 | minsk mazowiecki
# Processing Record 12 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 13 of Set 10 | margate
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 16 of Set 10 | lodja
# Processing Record 17 of Set 10 | asau
# Processing Record 18 of Set 10 | tecpan
# Processing Record 19 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 10 | gorom-gorom
# Processing Record 21 of Set 10 | marrakesh
# Processing Record 22 of Set 10 | nelson bay
# Processing Record 23 of Set 10 | sao gabriel da cachoeira
# Processing Record 24 of Set 10 | shingu
# Processing Record 25 of Set 10 | bosaso
# Processing Record 26 of Set 10 | humaita
# Processing Record 27 of Set 10 | hovd
# Processing Record 28 of Set 10 | great yarmouth
# Processing Record 29 of Set 10 | saucillo
# Processing Record 30 of Set 10 | kuryk
# Processing Record 31 of Set 10 | ngunguru
# Processing Record 32 of Set 10 | yeppoon
# Processing Record 33 of Set 10 | siguiri
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | shaunavon
# Processing Record 37 of Set 10 | chuy
# Processing Record 38 of Set 10 | kirovskiy
# Processing Record 39 of Set 10 | arcos
# Processing Record 40 of Set 10 | tutoia
# Processing Record 41 of Set 10 | saint-donat-de-montcalm
# Processing Record 42 of Set 10 | dajabon
# Processing Record 43 of Set 10 | grand gaube
# Processing Record 44 of Set 10 | san pedro
# Processing Record 45 of Set 10 | miracatu
# Processing Record 46 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 10 | arman
# Processing Record 48 of Set 10 | kilgore
# Processing Record 49 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 10 | cabedelo
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 11 | angoche
# Processing Record 4 of Set 11 | wamba
# Processing Record 5 of Set 11 | santa maria da vitoria
# Processing Record 6 of Set 11 | saurimo
# Processing Record 7 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 11 | monrovia
# Processing Record 9 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 11 | gravdal
# Processing Record 11 of Set 11 | glarus
# Processing Record 12 of Set 11 | sinnamary
# Processing Record 13 of Set 11 | deming
# Processing Record 14 of Set 11 | sola
# Processing Record 15 of Set 11 | xuanhua
# Processing Record 16 of Set 11 | anloga
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | teahupoo
# Processing Record 19 of Set 11 | padang
# Processing Record 20 of Set 11 | chum phae
# Processing Record 21 of Set 11 | am timan
# Processing Record 22 of Set 11 | kuhestan
# City not found. Skipping...
# Processing Record 23 of Set 11 | ulaangom
# Processing Record 24 of Set 11 | atar
# Processing Record 25 of Set 11 | esperance
# Processing Record 26 of Set 11 | naron
# Processing Record 27 of Set 11 | onda
# Processing Record 28 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 11 | nome
# Processing Record 30 of Set 11 | matara
# Processing Record 31 of Set 11 | oum hadjer
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 11 | rodrigues alves
# Processing Record 36 of Set 11 | sibolga
# Processing Record 37 of Set 11 | siparia
# Processing Record 38 of Set 11 | babu
# Processing Record 39 of Set 11 | paamiut
# Processing Record 40 of Set 11 | kavaratti
# Processing Record 41 of Set 11 | banyo
# Processing Record 42 of Set 11 | tocopilla
# Processing Record 43 of Set 11 | acari
# Processing Record 44 of Set 11 | pokoynoye
# Processing Record 45 of Set 11 | tacuarembo
# Processing Record 46 of Set 11 | norrtalje
# Processing Record 47 of Set 11 | qianan
# Processing Record 48 of Set 11 | roebourne
# Processing Record 49 of Set 11 | jutai
# Processing Record 50 of Set 11 | revin
# Processing Record 1 of Set 12 | morgan city
# Processing Record 2 of Set 12 | ous
# Processing Record 3 of Set 12 | impfondo
# Processing Record 4 of Set 12 | nykobing
# City not found. Skipping...
# Processing Record 5 of Set 12 | raudeberg
# Processing Record 6 of Set 12 | chumikan
# Processing Record 7 of Set 12 | saint-augustin
# Processing Record 8 of Set 12 | piacabucu
# Processing Record 9 of Set 12 | ulaanbaatar
# Processing Record 10 of Set 12 | chapais
# Processing Record 11 of Set 12 | sunyani
# Processing Record 12 of Set 12 | beyneu
# Processing Record 13 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | nagato
# Processing Record 17 of Set 12 | mayo
# Processing Record 18 of Set 12 | snezhnogorsk
# Processing Record 19 of Set 12 | noshiro
# Processing Record 20 of Set 12 | port blair
# Processing Record 21 of Set 12 | muroto
# Processing Record 22 of Set 12 | evensk
# Processing Record 23 of Set 12 | kentau
# Processing Record 24 of Set 12 | honiara
# Processing Record 25 of Set 12 | amudat
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | kerema
# Processing Record 28 of Set 12 | san estanislao
# Processing Record 29 of Set 12 | fez
# Processing Record 30 of Set 12 | oga
# Processing Record 31 of Set 12 | gladstone
# Processing Record 32 of Set 12 | mandera
# Processing Record 33 of Set 12 | dhidhdhoo
# Processing Record 34 of Set 12 | guarapari
# Processing Record 35 of Set 12 | kaohsiung
# Processing Record 36 of Set 12 | sechura
# Processing Record 37 of Set 12 | atambua
# Processing Record 38 of Set 12 | synya
# Processing Record 39 of Set 12 | mekhelta
# City not found. Skipping...
# Processing Record 40 of Set 12 | oranjemund
# Processing Record 41 of Set 12 | aguas vermelhas
# Processing Record 42 of Set 12 | kropachevo
# Processing Record 43 of Set 12 | tukrah
# Processing Record 44 of Set 12 | somerset
# Processing Record 45 of Set 12 | waipawa
# Processing Record 46 of Set 12 | kompaniyivka
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | alblasserdam
# Processing Record 49 of Set 12 | tafresh
# Processing Record 50 of Set 12 | dibulla
# Processing Record 1 of Set 13 | alice springs
# Processing Record 2 of Set 13 | nouakchott
# Processing Record 3 of Set 13 | alexander city
# Processing Record 4 of Set 13 | ratnagiri
# Processing Record 5 of Set 13 | san antonio
# Processing Record 6 of Set 13 | goma
# Processing Record 7 of Set 13 | mazyr
# Processing Record 8 of Set 13 | manica
# Processing Record 9 of Set 13 | erdenet
# Processing Record 10 of Set 13 | iskateley
# Processing Record 11 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 13 | taltal
# Processing Record 13 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 13 | kommunisticheskiy
# Processing Record 15 of Set 13 | iquique
# Processing Record 16 of Set 13 | otradnoye
# Processing Record 17 of Set 13 | mabaruma
# Processing Record 18 of Set 13 | ossora
# Processing Record 19 of Set 13 | mitu
# Processing Record 20 of Set 13 | mehran
# Processing Record 21 of Set 13 | oxelosund
# Processing Record 22 of Set 13 | ingham
# Processing Record 23 of Set 13 | calama
# Processing Record 24 of Set 13 | san quintin
# Processing Record 25 of Set 13 | floro
# Processing Record 26 of Set 13 | zemaiciu naumiestis
# Processing Record 27 of Set 13 | shubarkuduk
# Processing Record 28 of Set 13 | viedma
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | soeng sang
# Processing Record 31 of Set 13 | vostok
# Processing Record 32 of Set 13 | bud
# Processing Record 33 of Set 13 | chernenko
# Processing Record 34 of Set 13 | sakakah
# Processing Record 35 of Set 13 | gorontalo
# Processing Record 36 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 13 | zmeinogorsk
# Processing Record 38 of Set 13 | teguldet
# Processing Record 39 of Set 13 | roma
# Processing Record 40 of Set 13 | fairview
# Processing Record 41 of Set 13 | asfi
# Processing Record 42 of Set 13 | coracora
# Processing Record 43 of Set 13 | seoul
# Processing Record 44 of Set 13 | sora
# Processing Record 45 of Set 13 | khandyga
# Processing Record 46 of Set 13 | kitui
# Processing Record 47 of Set 13 | dali
# Processing Record 48 of Set 13 | carlos antonio lopez
# Processing Record 49 of Set 13 | bilibino
# Processing Record 50 of Set 13 | bonito
# Processing Record 1 of Set 14 | tongchuan
# Processing Record 2 of Set 14 | cayenne
# Processing Record 3 of Set 14 | sorsk
# Processing Record 4 of Set 14 | vikulovo
# Processing Record 5 of Set 14 | pacific grove
# Processing Record 6 of Set 14 | la asuncion
# Processing Record 7 of Set 14 | mount isa
# Processing Record 8 of Set 14 | san vicente
# Processing Record 9 of Set 14 | krasnyy yar
# Processing Record 10 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 14 | moroni
# Processing Record 12 of Set 14 | peski
# Processing Record 13 of Set 14 | terra santa
# Processing Record 14 of Set 14 | rosario do sul
# Processing Record 15 of Set 14 | sfantu gheorghe
# Processing Record 16 of Set 14 | kahului
# Processing Record 17 of Set 14 | dubai
# Processing Record 18 of Set 14 | mangrol
# Processing Record 19 of Set 14 | waren
# Processing Record 20 of Set 14 | manokwari
# Processing Record 21 of Set 14 | jacareacanga
# Processing Record 22 of Set 14 | verkhnetulomskiy
# Processing Record 23 of Set 14 | arraias
# Processing Record 24 of Set 14 | aloleng
# Processing Record 25 of Set 14 | tahe
# Processing Record 26 of Set 14 | komsomolskiy
# Processing Record 27 of Set 14 | kiama
# Processing Record 28 of Set 14 | nedjo
# Processing Record 29 of Set 14 | bereda
# Processing Record 30 of Set 14 | kusk
# City not found. Skipping...
# Processing Record 31 of Set 14 | machali
# Processing Record 32 of Set 14 | acapulco
# Processing Record 33 of Set 14 | mount barker
# Processing Record 34 of Set 14 | edendale
# Processing Record 35 of Set 14 | nouadhibou
# Processing Record 36 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | wooster
# Processing Record 38 of Set 14 | surazh
# Processing Record 39 of Set 14 | murdochville
# Processing Record 40 of Set 14 | noumea
# Processing Record 41 of Set 14 | mendrisio
# Processing Record 42 of Set 14 | imeni babushkina
# Processing Record 43 of Set 14 | muisne
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | araouane
# Processing Record 46 of Set 14 | slave lake
# Processing Record 47 of Set 14 | lewistown
# Processing Record 48 of Set 14 | fort nelson
# Processing Record 49 of Set 14 | bonga
# Processing Record 50 of Set 14 | kyakhta
# Processing Record 1 of Set 15 | labuhan
# Processing Record 2 of Set 15 | burgeo
# Processing Record 3 of Set 15 | ozinki
# Processing Record 4 of Set 15 | shelburne
# Processing Record 5 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 15 | mozarlandia
# Processing Record 7 of Set 15 | vestmannaeyjar
# Processing Record 8 of Set 15 | sapouy
# Processing Record 9 of Set 15 | ouesso
# Processing Record 10 of Set 15 | bima
# Processing Record 11 of Set 15 | rovaniemi
# Processing Record 12 of Set 15 | domingos martins
# Processing Record 13 of Set 15 | inongo
# Processing Record 14 of Set 15 | timbiqui
# Processing Record 15 of Set 15 | champerico
# Processing Record 16 of Set 15 | ulladulla
# Processing Record 17 of Set 15 | husavik
# Processing Record 18 of Set 15 | bayan
# Processing Record 19 of Set 15 | notodden
# Processing Record 20 of Set 15 | port shepstone
# Processing Record 21 of Set 15 | tucupita
# Processing Record 22 of Set 15 | haradok
# Processing Record 23 of Set 15 | pangoa
# Processing Record 24 of Set 15 | matamoros
# Processing Record 25 of Set 15 | awjilah
# Processing Record 26 of Set 15 | tabuk
# Processing Record 27 of Set 15 | nanakuli
# Processing Record 28 of Set 15 | bria
# Processing Record 29 of Set 15 | yarada
# Processing Record 30 of Set 15 | prince rupert
# Processing Record 31 of Set 15 | mae hong son
# Processing Record 32 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 15 | syracuse
# Processing Record 34 of Set 15 | bandarbeyla
# Processing Record 35 of Set 15 | xinqing
# Processing Record 36 of Set 15 | beloha
# Processing Record 37 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 15 | malesici
# Processing Record 39 of Set 15 | luderitz
# Processing Record 40 of Set 15 | araceli
# Processing Record 41 of Set 15 | sorland
# Processing Record 42 of Set 15 | arlit
# Processing Record 43 of Set 15 | mecca
# Processing Record 44 of Set 15 | bikaner
# Processing Record 45 of Set 15 | caxito
# Processing Record 46 of Set 15 | lac du bonnet
# Processing Record 47 of Set 15 | northam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bourail -21.5667  165.4833     75.13        81          89
# 1        Mataura -46.1927  168.8643     48.00        95          93
# 2         Albany  42.6001  -73.9662     43.00        71          96
# 3          Bafut   6.0833   10.1000     67.19        79         100
# 4      Upernavik  72.7868  -56.1549      4.89        86          99
# 5      Hithadhoo  -0.6000   73.0833     82.67        64           5
# 6        Ushuaia -54.8000  -68.3000     44.60        61          20
# 7  Leningradskiy  69.3833  178.4167     32.22        72          48
# 8          Avera  33.1940  -82.5271     57.20        56           1
# 9       Victoria  22.2855  114.1577     82.40        54          20
#
#    Wind Speed Country                 Date       Description
# 0        5.35      NC  2021-04-21 05:35:21   overcast clouds
# 1        8.99      NZ  2021-04-21 05:35:22   overcast clouds
# 2        4.99      US  2021-04-21 05:35:22   overcast clouds
# 3        2.68      CM  2021-04-21 05:35:23   overcast clouds
# 4        7.65      GL  2021-04-21 05:35:23   overcast clouds
# 5        3.89      MV  2021-04-21 05:35:24         clear sky
# 6        5.75      AR  2021-04-21 05:31:59        few clouds
# 7        7.29      RU  2021-04-21 05:35:25  scattered clouds
# 8        4.61      US  2021-04-21 05:35:25         clear sky
# 9        9.22      HK  2021-04-21 05:33:37        few clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
